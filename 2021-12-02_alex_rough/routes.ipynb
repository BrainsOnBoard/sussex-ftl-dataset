# %%
import sys
sys.path.append('../../..')

import matplotlib.pyplot as plt
import navbench as nb

dbs = [nb.Database('ftl00%d' % (i + 1)) for i in range(4)]

_, axes = plt.subplots(1, 2)
for i, ax in enumerate(axes):
    ax.plot(dbs[i * 2].x, dbs[i * 2].y, dbs[i * 2 + 1].x, dbs[i * 2 + 1].y)
    ax.axis('equal')
    ax.set_xlabel('x (m)')
    ax.set_ylabel('y (m)')
# Out:
# Loading database at ftl001...
# Database contains 188 images
# Loading database at ftl002...
# Database contains 192 images
# Loading database at ftl003...
# Database contains 450 images
# Loading database at ftl004...
# Database contains 425 images
